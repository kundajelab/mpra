# %%
import gzip
import numpy as np
import time
from scipy.stats import pearsonr, spearmanr, rankdata, ks_2samp
import matplotlib.pyplot as plt
import matplotlib

# %%
# !pwd

# %% [markdown]
# # Extract fragments that are nonzero in both reps or zero in both reps

# %%
from math import floor

signals = open('../../sureseq/SUREfragmentsignal3.txt')
header = signals.readline()

negativeSubsamples = [0.05, 0.1, 0.2, 0.4]

jitterStride = 100
rep1Data = []
rep2Data = []
rep1GoodData = []
rep2GoodData = []
posSignals = []
zeroSignals = []
# rep1GoodData = [[] for p in range(len(negativeSubsamples))]
# rep2GoodData = [[] for p in range(len(negativeSubsamples))]
# goodSignals = [[] for p in range(len(negativeSubsamples))]

i = 0
for line in signals:
    if (i-1) % 1e7 == 0:
        print "On fragment %s / " %(i-1) + '153000000'
    line = line.strip().split('\t')
    rep1Signal = float(line[4])
    rep2Signal = float(line[5])
    rep1Data.append(rep1Signal)
    rep2Data.append(rep2Signal)
    if rep1Signal > 0 and rep2Signal > 0:
        seqLen = int(line[2]) - int(line[1])
        if seqLen <= 2000:
            rep1GoodData.append(rep1Signal)
            rep2GoodData.append(rep2Signal)
#             avgSignal = float(line[6])
            avgSignal = (rep1Signal + rep2Signal) / 2 # Normal averaging, not based on reads
            name = line[0] + ":" + line[1] + "-" + line[2] + '(' + line[3] + ')'
            posSignals.append([line[0], line[1], line[2], name, avgSignal, line[3], rep1Signal, rep2Signal])
            # n for normal; that is, 5' to 3' on the sense strand; rc for reverse complement.
#             name1 = line[0] + ":" + line[1] + "-" + line[2] + '(' + line[3] + ',n)'
#             goodSignals.append([line[0], line[1], line[2], name1, avgSignal, line[3], rep1Signal, rep2Signal])
#             name2 = line[0] + ":" + line[1] + "-" + line[2] + '(' + line[3] + ',rc)'
#             goodSignals.append([line[0], line[1], line[2], name2, avgSignal, line[3], rep1Signal, rep2Signal])
#             numJitter = int(floor((1000 - seqLen / 2) / jitterStride) * 2 + 1)
#             print seqLen
#             print numJitter
#             for k in range(numJitter):
#                 name1Idx = name1 + ',' + str(k) + ')'
#                 goodSignals.append([line[0], line[1], line[2], name1Idx, avgSignal, line[3], rep1Signal, rep2Signal])
#                 name2Idx = name2 + ',' + str(k) + ')'
#                 goodSignals.append([line[0], line[1], line[2], name2Idx, avgSignal, line[3], rep1Signal, rep2Signal])
#     for j in range(len(negativeSubsamples)):
#         prob = negativeSubsamples[j]
#         if (seqLen <= 2000 and
#            (rep1Signal > 0 and rep2Signal > 0) or 
#            (rep1Signal == 0 and rep2Signal == 0 and np.random.uniform() < prob)):
#     #     if rep1Signal > 0 and rep2Signal > 0 and seqLen <= 2000:
#             rep1GoodData[j].append(rep1Signal)
#             rep2GoodData[j].append(rep2Signal)
#             name = line[0] + ":" + line[1] + "-" + line[2] + '(' + line[3] + ')'
#             avgSignal = float(line[6])
#             goodSignals[j].append([line[0], line[1], line[2], name, avgSignal, line[3], rep1Signal, rep2Signal])
#     if i > 200:
#         break
    elif rep1Signal == 0 and rep2Signal == 0:
        seqLen = int(line[2]) - int(line[1])
        if seqLen <= 2000:
            rep1GoodData.append(rep1Signal)
            rep2GoodData.append(rep2Signal)
#             avgSignal = float(line[6])
            avgSignal = (rep1Signal + rep2Signal) / 2 # Normal averaging, not based on reads
            name = line[0] + ":" + line[1] + "-" + line[2] + '(' + line[3] + ')'
            zeroSignals.append([line[0], line[1], line[2], name, avgSignal, line[3], rep1Signal, rep2Signal])
    i += 1
# Out:
# On fragment 0 / 153000000
# On fragment 10000000 / 153000000
# On fragment 20000000 / 153000000
# On fragment 30000000 / 153000000
# On fragment 40000000 / 153000000
# On fragment 50000000 / 153000000
# On fragment 60000000 / 153000000
# On fragment 70000000 / 153000000
# On fragment 80000000 / 153000000
# On fragment 90000000 / 153000000
# On fragment 100000000 / 153000000
# On fragment 110000000 / 153000000
# On fragment 120000000 / 153000000
# On fragment 130000000 / 153000000
# On fragment 140000000 / 153000000
# On fragment 150000000 / 153000000

# %%
# goodSignals = np.array(goodSignals)
# print goodSignals.shape
# numPositive = 2000000
# for k in range(len(goodSignals)):
#     prob = negativeSubsamples[k]
#     print("Length of array with " + str(prob) + " subsampling = " + str(len(goodSignals[k])) + ". "
#           "Expected length was approximately " + str(int(numPositive + prob * (i - numPositive))) + ".")

# print goodSignals[:10]
# print goodSignals[0][:5]

posSignals = np.array(posSignals)
print posSignals.shape
zeroSignals = np.array(zeroSignals)
print zeroSignals.shape

print posSignals[:10]
top_n = 500000
posSignals = posSignals[np.argsort(posSignals[:, 4].astype(np.float))[::-1][:top_n]]
print posSignals[:10]
# Out:
# (2090287, 8)
# (122870713, 8)
# [['chr1' '10225' '10368' 'chr1:10225-10368(+)' '1.59897252499' '+'
#   '2.11804651617' '1.07989853381']
#  ['chr1' '10271' '10772' 'chr1:10271-10772(+)' '43.9627107504' '+'
#   '31.7706977425' '56.1547237583']
#  ['chr1' '10271' '11710' 'chr1:10271-11710(-)' '9.61471042565' '-'
#   '10.5902325808' '8.63918827051']
#  ['chr1' '10587' '11454' 'chr1:10587-11454(-)' '117.494571624' '-'
#   '131.318884002' '103.670259246']
#  ['chr1' '11261' '12065' 'chr1:11261-12065(-)' '1.32899789154' '-'
#   '2.11804651617' '0.539949266907']
#  ['chr1' '11646' '12153' 'chr1:11646-12153(+)' '6.39589009996' '+'
#   '8.47218606467' '4.31959413525']
#  ['chr1' '13205' '14516' 'chr1:13205-14516(+)' '25.9565074609' '+'
#   '50.833116388' '1.07989853381']
#  ['chr1' '14380' '15220' 'chr1:14380-15220(-)' '7.4966639095' '-'
#   '6.3541395485' '8.63918827051']
#  ['chr1' '15546' '16038' 'chr1:15546-16038(+)' '3.71701904115' '+'
#   '6.3541395485' '1.07989853381']
# ...

# %%
from scipy.stats import zscore

print ("avgsignalmean = " + str(round(np.mean(goodSignals[:, 4].astype(np.float)), 4)) + 
       ", avgsignalsigma = " + str(round(np.std(goodSignals[:, 4].astype(np.float)), 4)))
avgSignalsNormalized = zscore(goodSignals[:, 4].astype(np.float))
print ("normavgsignalmean = " + str(round(np.mean(avgSignalsNormalized), 4)) + 
       ", normavgsignalsigma = " + str(round(np.std(avgSignalsNormalized), 4)))
rep1SignalsNormalized = zscore(goodSignals[:, 6].astype(np.float))
rep2SignalsNormalized = zscore(goodSignals[:, 7].astype(np.float))

goodSignalsNormalized = goodSignals
goodSignalsNormalized[:, 4] = avgSignalsNormalized.astype('string')
goodSignalsNormalized[:, 6] = rep1SignalsNormalized.astype('string')
goodSignalsNormalized[:, 7] = rep2SignalsNormalized.astype('string')

print goodSignalsNormalized[:10]
# Out:
# avgsignalmean = 10.799, avgsignalsigma = 23.4288
# normavgsignalmean = -0.0, normavgsignalsigma = 1.0
# [['chr1' '10225' '10368' 'chr1:10225-10368(+,n)' '-0.3926783801' '+'
#   '-0.44498273026' '-0.27509480653']
#  ['chr1' '10225' '10368' 'chr1:10225-10368(+,rc)' '-0.3926783801' '+'
#   '-0.44498273026' '-0.27509480653']
#  ['chr1' '10271' '10772' 'chr1:10271-10772(+,n)' '1.41550902214' '+'
#   '0.83396514836' '1.59931031754']
#  ['chr1' '10271' '10772' 'chr1:10271-10772(+,rc)' '1.41550902214' '+'
#   '0.83396514836' '1.59931031754']
#  ['chr1' '10271' '11710' 'chr1:10271-11710(-,n)' '-0.0505471872742' '-'
#   '-0.0795690506555' '-0.0178235149917']
#  ['chr1' '10271' '11710' 'chr1:10271-11710(-,rc)' '-0.0505471872742' '-'
#   '-0.0795690506555' '-0.0178235149917']
#  ['chr1' '10587' '11454' 'chr1:10587-11454(-,n)' '4.55402771913' '-'
#   '5.12757588371' '3.21644415006']
#  ['chr1' '10587' '11454' 'chr1:10587-11454(-,rc)' '4.55402771913' '-'
#   '5.12757588371' '3.21644415006']
# ...

# %%
for i in range(len(goodSignals)):
    count = 0
    arr = goodSignals[i]
    for j in range(len(arr)):
        if arr[j][4] > 0:
            count += 1
    print count
# Out:
# 2090287
# 2090287
# 2090287
# 2090287

# %%
header = 'chr\tstart\tend\tname\tavgSignal\tstrand\trep1Signal\trep2Signal'

np.savetxt(fname = '../data/fragmentData/top500kPositiveSignals.bed',
           fmt = '%s',
           X = posSignals,
           delimiter = '\t', 
           header = header,
           comments = '# ')

np.savetxt(fname = '../data/fragmentData/bothRepZeroSignals.bed',
           fmt = '%s',
           X = zeroSignals,
           delimiter = '\t', 
           header = header,
           comments = '# ')

# for j in range(len(negativeSubsamples)):
#     prob = negativeSubsamples[j]
#     np.savetxt(fname = '../data/classificationSignals' + str(prob) + 'NegativeSubsample.bed',
#                fmt = '%s',
#                X = goodSignals[j],
#                delimiter = '\t', 
#                header = header,
#                comments='')

# %%
print pearsonr(rep1GoodData, rep2GoodData)
print spearmanr(rep1GoodData, rep2GoodData)

# %%
cnt = 0
for i in range(len(rep1GoodData)):
    if rep1GoodData[i] > 0:
        cnt += 1

# %%
print float(cnt) / len(rep1GoodData) * 100.0

# %%
rep1Data = np.array(rep1Data)
rep2Data = np.array(rep2Data)
rep1GoodData = np.array(rep1GoodData)
rep1GoodData = np.array(rep1GoodData)

# %%
L = len(rep1Data)

# %%
print 100.0 * np.sum(rep1Data > 0) / L
print 100.0 * np.sum(rep2Data > 0) / L
print 100.0 * np.sum(np.logical_and(rep1Data == 0, rep2Data == 0)) / L
print 100.0 * np.sum(np.logical_and(rep1Data > 0, rep2Data == 0)) / L
print 100.0 * np.sum(np.logical_and(rep1Data == 0, rep2Data > 0)) / L
print 100.0 * np.sum(np.logical_and(rep1Data > 0, rep2Data > 0)) / L

# %%
greaterThanZeroOrZero = np.logical_or(np.logical_and(rep1Data > 0, rep2Data > 0), np.logical_and(rep1Data == 0, rep2Data == 0))
print spearmanr(rep1Data[greaterThanZeroOrZero], rep2Data[greaterThanZeroOrZero])

# %% [markdown]
# # Create train+val+test splits, fragment labels, fragment features

# %%
# IF DOING CLASSIFICATION SUBSAMPLING

import os
import sys

# runName = 'Jun22ClassificationWithoutQc'
chrs = ['chr' + str(i) for i in range(1, 23)]
valChrs = ['chr8']
testChrs = ['chr18']
trainChrs = chrs
trainChrs = [chrom for chrom in trainChrs if chrom not in valChrs and chrom not in testChrs]
# print trainChrs

for i in range(len(negativeSubsamples)):
    prob = negativeSubsamples[i]
    runName = 'Jun26Classification' + str(prob) + 'NegativeSubsample'
    os.system("mkdir ../splits/" + runName + "/")
    dataMatrix = open('../data/classificationSignals' + str(prob) + 'NegativeSubsample.bed', 'r').readlines()[2:]
    # print len(dataMatrix)
    # sys.exit(0)
    # header = dataMatrix.readline()
    # spacer = dataMatrix.readline()

    trainSplit = open('../splits/' + runName + '/train_split.txt', 'w')
    valSplit = open('../splits/' + runName + '/val_split.txt', 'w')
    testSplit = open('../splits/' + runName + '/test_split.txt', 'w')

    # runName = 'Jun22ClassificationWithoutQc'
    classificationLabels = open('../labels/labels' + runName + '.txt', 'w')
    classificationLabels.write('name\tavg\trep1\trep2\n')
    # runName = 'Jun22RegressionWithoutQc'
#     regressionLabels = open('../labels/labels' + runName + '.txt', 'w')
#     regressionLabels.write('name\tavg\trep1\trep2\n')

    counts = [0,0,0,0]
    for line in dataMatrix:
        line = line.strip().split('\t')
        chrom = line[0]
        fragmentName = line[3]
        if chrom in chrs:
            counts[3] += 1

        # add fragment names to their respective split files
        if chrom in trainChrs:
            trainSplit.write(fragmentName + '\n')
            counts[0] += 1
        elif chrom in valChrs:
            valSplit.write(fragmentName + '\n')
            counts[1] += 1
        elif chrom in testChrs:
            testSplit.write(fragmentName + '\n')
            counts[2] += 1

        avgSignal = float(line[4])
        rep1Signal = float(line[6])
        rep2Signal = float(line[7])

        # if the fragment was in any of the relevant splits, then add it to the labels file
        if chrom in trainChrs or chrom in valChrs or chrom in testChrs:
            classificationLabel = fragmentName + '\t' + str(int(avgSignal > 0)) + '\t' + \
                                  str(int(rep1Signal > 0)) + '\t' + str(int(rep2Signal > 0)) + '\n'
            classificationLabels.write(classificationLabel)

#             regressionLabel = fragmentName + '\t' + str(avgSignal) + '\t' + \
#                               str(rep1Signal) + '\t' + str(rep2Signal) + '\n'
#             regressionLabels.write(regressionLabel)

    trainSplit.close()
    valSplit.close()
    testSplit.close()
    classificationLabels.close()
#     regressionLabels.close()

    print "train size = " + str(counts[0]) + " fragments"
    print "validation size = " + str(counts[1]) + " fragments"
    print "test size = " + str(counts[2]) + " fragments"
    print "total data size = " + str(counts[3]) + " fragments"
# Out:
# train size = 7469090 fragments
# validation size = 419458 fragments
# test size = 214691 fragments
# total data size = 8103239 fragments
# train size = 13094253 fragments
# validation size = 738079 fragments
# test size = 377272 fragments
# total data size = 14209604 fragments
# train size = 24324957 fragments
# validation size = 1373216 fragments
# test size = 702141 fragments
# total data size = 26400314 fragments
# train size = 46805790 fragments
# validation size = 2640660 fragments
# test size = 1352587 fragments
# total data size = 50799037 fragments

# %%
# IF ONLY MAKING ONE SET OF FILES - REGRESSION OR CLASSIFICATION WITHOUT VARIOUS SUBSAMPLING LEVELS

import os
import sys

runName = 'regression_jul12_normalized'
chrs = ['chr' + str(i) for i in range(1, 23)] + ['chrX', 'chrY']
valChrs = ['chr8']
testChrs = ['chr18']
trainChrs = chrs
trainChrs = [chrom for chrom in trainChrs if chrom not in valChrs and chrom not in testChrs]

os.system("mkdir ../splits/" + runName + "/")
dataMatrix = open('../data/positiveSignalsNormalized.bed', 'r').readlines()[1:]

trainSplit = open('../splits/' + runName + '/train_split.txt', 'w')
valSplit = open('../splits/' + runName + '/val_split.txt', 'w')
testSplit = open('../splits/' + runName + '/test_split.txt', 'w')

# classificationLabels = open('../labels/labels' + runName + '.txt', 'w')
# classificationLabels.write('name\tavg\trep1\trep2\n')
regressionLabels = open('../labels/labels_' + runName + '.txt', 'w')
regressionLabels.write('name\tavg\trep1\trep2\n')

counts = [0,0,0,0]
for line in dataMatrix:
    line = line.strip().split('\t')
    chrom = line[0]
    fragmentName = line[3]
    if chrom in chrs:
        counts[3] += 1

    # add fragment names to their respective split files
    if chrom in trainChrs:
        trainSplit.write(fragmentName + '\n')
        counts[0] += 1
    elif chrom in valChrs:
        valSplit.write(fragmentName + '\n')
        counts[1] += 1
    elif chrom in testChrs:
        testSplit.write(fragmentName + '\n')
        counts[2] += 1

    avgSignal = float(line[4])
    rep1Signal = float(line[6])
    rep2Signal = float(line[7])

    # if the fragment was in any of the relevant splits, then add it to the labels file
    if chrom in trainChrs or chrom in valChrs or chrom in testChrs:
#         classificationLabel = fragmentName + '\t' + str(int(avgSignal > 0)) + '\t' + \
#                               str(int(rep1Signal > 0)) + '\t' + str(int(rep2Signal > 0)) + '\n'
#         classificationLabels.write(classificationLabel)

        regressionLabel = fragmentName + '\t' + str(avgSignal) + '\t' + \
                          str(rep1Signal) + '\t' + str(rep2Signal) + '\n'
        regressionLabels.write(regressionLabel)

trainSplit.close()
valSplit.close()
testSplit.close()
# classificationLabels.close()
regressionLabels.close()

print "train size = " + str(counts[0]) + " fragments"
print "validation size = " + str(counts[1]) + " fragments"
print "test size = " + str(counts[2]) + " fragments"
print "total data size = " + str(counts[3]) + " fragments"
# Out:
# train size = 3858444 fragments
# validation size = 205984 fragments
# test size = 103676 fragments
# total data size = 4168104 fragments

# %%
# !gzip ../splits/*.txt
# !gzip ../labels/*.txt

# %% [markdown]
# # BedTools getfasta command to extract sequences

# %%
# !source activate mommadragonn

# %%
import subprocess
for prob in negativeSubsamples:
    filename = "classificationSignals" + str(prob) + "NegativeSubsample.bed"
    cmd = ("bedtools getfasta -fi ../../../data/hg19.fa" +  
           " -bed ../data/" + filename + 
           " -s -fo ../features/sequencesJun26Classification" + str(prob) + "NegativeSubsample.fa")
    print cmd
#     out = subprocess.call(cmd)
#     print out
# Out:
# bedtools getfasta -fi ../../../data/hg19.fa -bed ../data/classificationSignals0.05NegativeSubsample.bed -s -fo ../features/sequencesJun26Classification0.05NegativeSubsample.fa
# bedtools getfasta -fi ../../../data/hg19.fa -bed ../data/classificationSignals0.1NegativeSubsample.bed -s -fo ../features/sequencesJun26Classification0.1NegativeSubsample.fa
# bedtools getfasta -fi ../../../data/hg19.fa -bed ../data/classificationSignals0.2NegativeSubsample.bed -s -fo ../features/sequencesJun26Classification0.2NegativeSubsample.fa
# bedtools getfasta -fi ../../../data/hg19.fa -bed ../data/classificationSignals0.4NegativeSubsample.bed -s -fo ../features/sequencesJun26Classification0.4NegativeSubsample.fa

# %% [markdown]
# # Prep sequences for HOMER analysis

# %%
# fileName = 'top500kSureSequencesUnstrand.fa'
fileName = 'bothRepZeroSequencesUnstrand.fa'

print "on file " + fileName
sequences = open('../features/homer/' + fileName, 'r')
# processedsequences = open('../features/homer/top500kSureSequences.fa', 'w')
processedsequences = open('../features/homer/bothRepZeroSequences.fa', 'w')

print "padding..."

i = 0
for line in sequences:
    if i % 2 == 0:
        # bedtools does weird stuff with the names, so let's get the actual name
        name = line.strip().split('::')[0]
        strand = name[name.find('(') + 1] # get the strand; it's the first char to the left of the comma
        processedsequences.write(line.strip().split('::')[0] + '\n')
        
    else:
        seq = line.strip()
        
        # convert sequence to uppercase for standardization
        seq = seq.upper()
        
        # if minus strand, get the complement sequence
        if strand == '-':
            seq = comp(seq)
        
        processedsequences.write(seq + '\n')
    i += 1
    
processedsequences.close()
# Out:
# on file top500kSureSequencesUnstrand.fa
# padding...

# %% [markdown]
# # Reverse complement, pad, and jitter (renamed) fasta sequences after using bedtools

# %%
import string
nucleotideMap = string.maketrans('ACGT', 'TGCA')

def rev(seq):
    return seq[::-1]

def comp(seq):
    return seq.translate(nucleotideMap)

def rev_comp(seq):
    return rev(comp(seq))

# test = 'ATGCTTACCG'
# print test
# print rev(test)
# print comp(test)
# print rev_comp(test)

# %%
runName = 'regression_jul7_strands_augmented'
fileName = 'sequences_' + runName + '.fa'

print "on file " + fileName
sequences = open('../features/' + fileName, 'r')
paddedSequences = open('../features/padded' + fileName, 'w')

print "padding..."

jitterStride = 100
PADDED_LENGTH = 2000
i = 0
strand = '+'
orientation = 'n'
for line in sequences:
    if i % 2 == 0:
        # bedtools does weird stuff with the names, so let's get the actual name
        name = line.strip().split('::')[0]
        strand = name.split(',')[0][-1] # get the strand; it's the first char to the left of the comma
        orientation = name.split(',')[1][0] # get the orientation; its the first 1-2 chars to the right of comma
        if orientation == 'r': # if the first char was r, it's revcomp, so lets be verbose about that
            orientation = 'rc'
        jitterIndex = int(name.split(',')[2][0])
        paddedSequences.write(line.strip().split('::')[0] + '\n')
        
    else:
        seq = line.strip()
        
        # convert sequence to uppercase for standardization
        seq = seq.upper()
        
        # if minus strand, get the complement sequence
        if strand == '-':
            seq = comp(seq)
            
        # if reverse complement (an augmentation fragment), convert to revcomp
        # note that for minus strand sequences, revcomp of the complement is the reverse
        if orientation == 'rc':
            seq = rev_comp(seq)
        
        # pad the ends of the sequence with 'N' characters, which map to [0 0 0 0].T
        # where the sequence lies with respect to the pads depends on the index is encoded in the name
        seqLen = len(seq)
        numJitter = int(floor((1000 - seqLen / 2) / jitterStride) * 2 + 1)
        scaledJitterIndex = (jitterIndex - numJitter / 2)
        seqStart = (1000 - seqLen / 2) + jitterStride * scaledJitterIndex
        seqEnd = seqStart + seqLen - 1
        newSeq = 'N' * (seqStart - 1) + seq + 'N' * (2000 - seqEnd)
#         padLength = (PADDED_LENGTH - seqLen) / 2
#         # pad on both sides, with the sequence centered
#         newSeq = 'N' * padLength + seq + 'N' * padLength 
        if len(newSeq) < PADDED_LENGTH:
            newSeq += 'N' * (PADDED_LENGTH - len(newSeq))
        if len(newSeq) > PADDED_LENGTH:
            newSeq = newSeq[:2000]
        paddedSequences.write(newSeq + '\n')
    i += 1
    
paddedSequences.close()

# subsampleValues = [0.1, 0.2, 0.4]
# for prob in subsampleValues:
#     fileName = 'sequencesJun26Classification' + str(prob) + 'NegativeSubsample.fa'
#     print "on file " + fileName
#     sequences = open('../features/' + fileName, 'r')
#     paddedSequences = open('../features/padded' + fileName, 'w')

#     print "padding..."

#     PADDED_LENGTH = 2000
#     i = 0
#     for line in sequences:
#         if i % 2 == 0:
#             paddedSequences.write(line)
#         else:
#             seq = line.strip()
#             length = len(seq)
#             padLength = (PADDED_LENGTH - length) / 2
#             newSeq = 'N' * padLength + seq + 'N' * padLength
#             if len(newSeq) < PADDED_LENGTH:
#                 newSeq += 'N'
#             paddedSequences.write(newSeq + '\n')
#         i += 1
# Out:
# on file sequences_regression_jul7_strands_augmented.fa
# padding...

# %%
# !pwd

# %% [markdown]
# # Check correctness of features and labels files

# %%
import gzip

sequences = open("../features/paddedsequencesJun26Classification0.05NegativeSubsample.fa", 'r')
i = 0
for line in sequences:
    if i%2 == 0:
        print len(line.strip())
    if i > 100:
        break
# Out:
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2006
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# 20
# 2000
# ...
